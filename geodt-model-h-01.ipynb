# %% [markdown]
# <img src="./geodt-logo.png" alt="isolated" width="200"/>

# %% [markdown]
# **GeoDT Model 01: Vertical model of groundwater flow**

# %% [markdown]
# Model description ...

# %% [markdown]
# ***Step 1***: Geometry

# %% [markdown]
# 1.1: Defining points manually

# %%
import numpy as np
import matplotlib.pyplot as plt 
points = np.array([[0,-2000],[0,200],[1000,400],[2000,300],[3000,300],[4000,500],[5000,200],[8000,200],[10000,300],[10000,-2000],[0,-2000]]) # array of coordinates in the form [x,y]
x1, y1 = zip(*points)
plt.axis('equal')
plt.plot(x1,y1,'.-')

# %% [markdown]
# 1.2: Reading points from shapefile (shp2vtk, tool from Markus)

# %% [markdown]
# ***Step 2***: Meshing

# %% [markdown]
# 2.1: convert geometry points to a gmsh surface for meshing

# %% [markdown]
# 2.2: run gmsh for meshing

# %% [markdown]
# 2.3: read mesh from file (provided by Ali)

# %% [markdown]
# ***Step 3***: Extracting boundary meshes

# %% [markdown]
# ***Step 4***: Set-up ogs project (H process)
